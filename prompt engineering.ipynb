# %%
import openai
openai.api_key = "your-api-key"

def classify_sentiment(chat_text):
    prompt = f"""
You are a helpful assistant that classifies customer support messages.

### Instructions:
1. Read the message between <message> tags.
2. Classify the sentiment as one of: Positive, Neutral, Negative.
3. Return the result in JSON format with keys 'sentiment' and 'reason'.

<message>
{chat_text}
</message>
"""

    response = openai.ChatCompletion.create(
        model="gpt-4",
        messages=[
            {"role": "system", "content": "You are a sentiment analysis expert."},
            {"role": "user", "content": prompt}
        ],
        temperature=0.0
    )

    return response['choices'][0]['message']['content']

# Example usage
chat = "I'm really disappointed with the delay in my order. This is unacceptable."
result = classify_sentiment(chat)
print(result)
# Out:
# ---------------------------------------------------------------------------
# AuthenticationError                       Traceback (most recent call last)
# Cell In[2], line 31
#      29 # Example usage
#      30 chat = "I'm really disappointed with the delay in my order. This is unacceptable."
# ---> 31 result = classify_sentiment(chat)
#      32 print(result)
#
# Cell In[2], line 18, in classify_sentiment(chat_text)
#       4 def classify_sentiment(chat_text):
#       5     prompt = f"""
#       6 You are a helpful assistant that classifies customer support messages.
#       7
#    (...)
#      15 </message>
#      16 """
# ---> 18     response = openai.ChatCompletion.create(
#      19         model="gpt-4",
#      20         messages=[
#      21             {"role": "system", "content": "You are a sentiment analysis expert."},
#      22             {"role": "user", "content": prompt}
#      23         ],
#      24         temperature=0.0
#      25     )
# ...

# %%
import openai
# optional; defaults to `os.environ['OPENAI_API_KEY']`
openai.api_key = '...'

# all client options can be configured just like the `OpenAI` instantiation counterpart
openai.base_url = "https://..."
openai.default_headers = {"x-foo": "true"}

completion = openai.chat.completions.create(
    model="gpt-4",
    messages=[
        {
            "role": "user",
            "content": "How do I output all files in a directory using Python?",
        },
    ],
)
print(completion.choices[0].message.content)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[3], line 9
#       6 openai.base_url = "https://..."
#       7 openai.default_headers = {"x-foo": "true"}
# ----> 9 completion = openai.chat.completions.create(
#      10     model="gpt-4",
#      11     messages=[
#      12         {
#      13             "role": "user",
#      14             "content": "How do I output all files in a directory using Python?",
#      15         },
#      16     ],
#      17 )
#      18 print(completion.choices[0].message.content)
#
# AttributeError: module 'openai' has no attribute 'chat'
